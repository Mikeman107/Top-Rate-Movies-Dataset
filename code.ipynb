# %%
import pandas as pd 
import requests

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0NTgwMDQxNmE0ZGExNTdkNjgyYjEwMjY4NTg0ZTQzYiIsIm5iZiI6MTcyMDY5MzMyOS4wMjk5NzYsInN1YiI6IjY2OGZhODI5MWYxZmM5MDgxM2Y2YzlmNiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.8LTCkPBJk2S2gL-fNR0l27iyY7mStpuNyVjW2bNT-3Y"
}

dfs = []
df = pd.DataFrame()

for i in range(1,476):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i), headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[["adult","backdrop_path","id","original_language","original_title","popularity","poster_path","release_date","title","vote_average","vote_count"]]
    dfs.append(temp_df)
    
df = pd.concat(dfs , ignore_index=True)
df.to_csv("C:/Users/Lenovo/OneDrive/Desktop/py/movies-Info.csv")

# %%
data = pd.read_csv("C://Users//Lenovo//OneDrive//Desktop//py//movies-Info.csv")
data
# Out:
#       Unnamed: 0  adult                     backdrop_path     id  \
# 0              0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg    278
# 1              1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg    238
# 2              2  False  /b6w7gKLQLS2zw4JK0XmKgQ4gnzr.jpg    240
# 3              3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg    424
# 4              4  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg    389
# ...          ...    ...                               ...    ...
# 9482        9482  False  /lcLyZzhB1ctfdH0hGBsTFrbflqP.jpg  12142
# 9483        9483  False  /5V6jAFS0Q49SI07qjyFRMYlbfR9.jpg  13805
# 9484        9484  False  /aNUEHLNsNMprLZt6fjf5nqDq6er.jpg  11059
# 9485        9485  False  /oHrrgAPEKpz0S1ofQntiZNrmGrM.jpg  14164
# 9486        9486  False  /wDrs28ZYYnXVIeb87H0dCYlWiFA.jpg  40016
#
#      original_language              original_title  popularity  \
# 0                   en    The Shawshank Redemption     152.053
# ...
